# %%
pip install transformers sentencepiece torch
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch
print(torch.__version__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import torch
#       2 print(torch.__version__)
#
# File c:\Users\mohin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\__init__.py:2169
#    2153 ################################################################################
#    2154 # Import most common subpackages
#    2155 ################################################################################
#    (...)   2160
#    2161 # needs to be before import torch.nn as nn to avoid circular dependencies
#    2162 from torch.autograd import (  # usort: skip
#    2163     enable_grad as enable_grad,
#    2164     inference_mode as inference_mode,
#    2165     no_grad as no_grad,
#    2166     set_grad_enabled as set_grad_enabled,
#    2167 )
# -> 2169 from torch import (
#    2170     __config__ as __config__,
# ...

# %% [markdown]
# NER bsically Predicts a label for each token (word or subword).
# "Barack Obama was born in Hawaii."
#
# → [("Barack Obama", PERSON), ("Hawaii", LOCATION)]

# %%
import torch
from transformers import pipeline

ner = pipeline("ner", model="dslim/bert-base-NER", aggregation_strategy="simple")
results = ner("My name is Mohini and I live in Mumbai.")
print(results)
# Out:
# Some weights of the model checkpoint at dslim/bert-base-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu
# [{'entity_group': 'PER', 'score': np.float32(0.7183201), 'word': 'Mohin', 'start': 11, 'end': 16}, {'entity_group': 'LOC', 'score': np.float32(0.9992071), 'word': 'Mumbai', 'start': 32, 'end': 38}]

# %% [markdown]
# Sentence segmentation & clause chunking logic

# %%
pip install spacy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spacy
from spacy.language import Language
nlp=spacy.load("en_core_web_sm")
@Language.component("set_custom_boundaries")
def set_custom_boundaries(doc):
    for token in doc[:-1]:
        if token.text in [";","but","and","although","however","but","Hence"]:
            doc[token.i+1].is_sent_start = True
    return doc 

if "set_custom_boundaries" not in nlp.pipe_names:
    nlp.add_pipe("set_custom_boundaries", before="parser")


def extract_clauses(text):
    doc=nlp(text)
    return [sent.text.strip() for sent in doc.sents]          




text = "Although the campaign ran well, it failed to generate revenue; the team is now revising it."
print(extract_clauses(text))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import spacy
#       2 from spacy.language import Language
#       3 nlp=spacy.load("en_core_web_sm")
#
# File c:\Users\mohin\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\__init__.py:6
#       3 from typing import Any, Dict, Iterable, Union
#       5 # set library-specific custom warning handling before doing anything else
# ----> 6 from .errors import setup_default_warnings
#       8 setup_default_warnings()  # noqa: E402
#      10 # These are imported as part of the API
#
# File c:\Users\mohin\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\errors.py:3
#       1 import warnings
# ----> 3 from .compat import Literal
#       6 class ErrorsWithCodes(type):
#       7     def __getattribute__(self, code):
#
# ...

# %%
pip install transformers
# Out:
# ...
#   Using cached safetensors-0.5.3-cp38-abi3-win_amd64.whl.metadata (3.9 kB)
# ...
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/10.8 MB ? eta -:--:--
#    - -------------------------------------- 0.5/10.8 MB 1.1 MB/s eta 0:00:10
#    --- ------------------------------------ 1.0/10.8 MB 1.6 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.6/10.8 MB 1.9 MB/s eta 0:00:05
#    ------- -------------------------------- 2.1/10.8 MB 2.0 MB/s eta 0:00:05
#    -------- ------------------------------- 2.4/10.8 MB 2.0 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.9/10.8 MB 2.1 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.1/10.8 MB 2.0 MB/s eta 0:00:04
# ...

# %%
pip install torch
# Out:
# ...
#   Using cached networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# ...
#    ---------------------------------------- 0.0/216.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/216.1 MB ? eta -:--:--
#    ---------------------------------------- 1.0/216.1 MB 2.5 MB/s eta 0:01:25
#    ---------------------------------------- 1.3/216.1 MB 2.4 MB/s eta 0:01:30
#    ---------------------------------------- 1.3/216.1 MB 2.4 MB/s eta 0:01:30
#    ---------------------------------------- 1.3/216.1 MB 2.4 MB/s eta 0:01:30
#    ---------------------------------------- 1.6/216.1 MB 1.2 MB/s eta 0:02:59
#    ---------------------------------------- 1.8/216.1 MB 1.2 MB/s eta 0:02:53
#    ---------------------------------------- 1.8/216.1 MB 1.2 MB/s eta 0:02:53
#    ---------------------------------------- 2.1/216.1 MB 1.2 MB/s eta 0:03:02
#    ---------------------------------------- 2.4/216.1 MB 1.1 MB/s eta 0:03:15
# ...

# %%
import torch
from transformers import pipeline
from typing import List

class Summarize:
    def __init__(self, model_name: str = "facebook/bart-large-cnn"):
        self.summarizer = pipeline("summarization", model=model_name)

    def summarize(self, text: str, max_length: int = 150, min_length: int = 30) -> str:
        if not text.strip():
            return "Input text is empty. Please provide valid text for summarization."
        
        summary = self.summarizer(text, max_length=max_length, min_length=min_length, do_sample=False)
        return summary[0]['summary_text'] if summary else "No summary generated."
    
s= Summarize()
text = """This Agreement is made between the Client and the Consultant.
The Consultant shall provide services including market research, analysis, and reporting.   
The Client agrees to pay all fees within 30 days of invoicing.
Termination of this Agreement requires a 30-day written notice from either party."""
print("Summary:\n", s.summarize(text))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import torch
#       2 from transformers import pipeline
#       3 from typing import List
#
# File c:\Users\mohin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\__init__.py:2169
#    2153 ################################################################################
#    2154 # Import most common subpackages
#    2155 ################################################################################
#    (...)   2160
#    2161 # needs to be before import torch.nn as nn to avoid circular dependencies
#    2162 from torch.autograd import (  # usort: skip
#    2163     enable_grad as enable_grad,
#    2164     inference_mode as inference_mode,
#    2165     no_grad as no_grad,
#    2166     set_grad_enabled as set_grad_enabled,
#    2167 )
# -> 2169 from torch import (
# ...

# %%
pip install faiss-cpu>=1.7.4
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
